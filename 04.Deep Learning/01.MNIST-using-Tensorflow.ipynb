# %% [markdown]
# ## MNIST-using-Tensorflow >>

# %%
#imports
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np

# %%
#Loading data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#Normalize the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## CNN Architectures >>

# %%
#CNN01
model1 = tf.keras.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
#CNN02
model2 = tf.keras.Sequential([
    layers.Conv2D(16, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
#CNN03
model3 = tf.keras.Sequential([
    layers.Conv2D(8, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.Conv2D(16, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
#Final compilation of models
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Training the
history1 = model1.fit(x_train.reshape(-1,28,28,1), y_train, epochs=5, validation_data=(x_test.reshape(-1,28,28,1), y_test))
history2 = model2.fit(x_train.reshape(-1,28,28,1), y_train, epochs=5, validation_data=(x_test.reshape(-1,28,28,1), y_test))
history3 = model3.fit(x_train.reshape(-1,28,28,1), y_train, epochs=5, validation_data=(x_test.reshape(-1,28,28,1), y_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 18s 4ms/step - loss: 0.1513 - accuracy: 0.9546 - val_loss: 0.0654 - val_accuracy: 0.9779
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0500 - accuracy: 0.9849 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0334 - accuracy: 0.9892 - val_loss: 0.0432 - val_accuracy: 0.9862
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0441 - val_accuracy: 0.9863
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0515 - val_accuracy: 0.9849
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1509 - accuracy: 0.9548 - val_loss: 0.0486 - val_accuracy: 0.9844
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0482 - accuracy: 0.9853 - val_loss: 0.0372 - val_accuracy: 0.9879
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0283 - val_accuracy: 0.9899
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0253 - accuracy: 0.9919 - val_loss: 0.0320 - val_accuracy: 0.9893
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0263 - val_accuracy: 0.9915
# Epoch 1/5
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1745 - accuracy: 0.9477 - val_loss: 0.0648 - val_accuracy: 0.9802
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0566 - accuracy: 0.9830 - val_loss: 0.0504 - val_accuracy: 0.9843
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0375 - accuracy: 0.9885 - val_loss: 0.0420 - val_accuracy: 0.9852
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.0463 - val_accuracy: 0.9854
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.0358 - val_accuracy: 0.9881

# %% [markdown]
# ## Evaluation of CNN models >>

# %%
#Evaluation
test_loss1, test_acc1 = model1.evaluate(x_test.reshape(-1,28,28,1), y_test)
test_loss2, test_acc2 = model2.evaluate(x_test.reshape(-1,28,28,1), y_test)
test_loss3, test_acc3 = model3.evaluate(x_test.reshape(-1,28,28,1), y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0515 - accuracy: 0.9849
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.9915
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0358 - accuracy: 0.9881

# %%
#Scores
print("Test Accuracy for Model 1:", test_acc1)
print("Test Accuracy for Model 2:", test_acc2)
print("Test Accuracy for Model 3:", test_acc3)
# Out:
# Test Accuracy for Model 1: 0.9848999977111816
# Test Accuracy for Model 2: 0.9915000200271606
# Test Accuracy for Model 3: 0.988099992275238

# %%
#Accuracy and parameters
models = ['Model 1', 'Model 2', 'Model 3']
test_accs = [test_acc1, test_acc2, test_acc3]
num_params = [model1.count_params(), model2.count_params(), model3.count_params()]
df = pd.DataFrame({'Model':models, 'Test Accuracy':test_accs, 'Number of Parameters':num_params})

# %%
df
# Out:
#      Model  Test Accuracy  Number of Parameters
# 0  Model 1         0.9849                693962
# 1  Model 2         0.9915                108618
# 2  Model 3         0.9881                149418
